# %% [markdown]
# ## 📘 0. Introduction: Data Governance with SQL (with Python)
# This notebook demonstrates how to use SQL to build a simple employee management database. It emphasizes data governance principles such as referential integrity, data validation, and clean schema design.

# %%
# We use sqlite3 to interact with the database 
# and pandas to format query results as tables
import sqlite3
import pandas as pd

# %% [markdown]
# ## 🧱 1. Initialize SQLite Database

# %% [markdown]
# In this section, we create an in-memory SQLite database and set up a cursor object to execute SQL commands. This temporary database exists only while the notebook is running, making it ideal for experimentation and instruction.

# %%
# Connect to an in-memory SQLite database
con = sqlite3.connect(':memory:')

# Create a cursor object to execute SQL commands
cur = con.cursor()

# %% [markdown]
# ## 🛠️ 2. Define SQL Execution Helper Functions

# %% [markdown]
# This section defines reusable helper functions that let us execute SQL scripts and queries from files or strings. You don't need to modify or deeply understand this code. These are just functions to run SQL queries or scripts throughout the notebook.

# %%
# Define a helper function to execute a SQL script inside a file
def execute_sql_script_from_file(filepath):
    try:
        with open(filepath, 'r') as f:
            sql_script = f.read()

        print(f'🖥 Executing SQL script from file {filepath}')
        cur.executescript(sql_script)
        print(f"✅ Successfully executed SQL script from file {filepath}")
    except Exception as e:
        print(f"❌ An error occurred: {e}")


# Define a helper function to execute a SQL query string
def execute_sql_query(query):
    try:
        # Execute the query
        cur.execute(query)

        if cur.description is not None:
            # Fetch all rows and column names
            rows = cur.fetchall()
            column_names = [description[0] for description in cur.description]
    
            if rows:
                print(f"✅ Query executed successfully. {len(rows)} row{'s' if len(rows) >= 2 else ''} to display.")
            else:
                print("✅ Query executed successfully. No results to display.")
    
            df = pd.DataFrame(rows, columns=column_names)
            display(df.style.hide(axis='index'))
        else:
            # For INSERT, UPDATE, DELETE, etc.
            print("✅ Query executed successfully. No results to display.")
    except sqlite3.Error as e:
        print(f"❌ An error occurred: {e}")

# Define a helper function to execute a SQL query inside a file
def execute_sql_query_from_file(filepath):
        with open(filepath, 'r') as f:
            query_string = f.read()

            print(f'🖥 Executing SQL query from file {filepath}')
            execute_sql_query(query_string)

# %% [markdown]
# ## 🗂️ 3. Create and Populate Database Tables

# %% [markdown]
# ### 3.1 Create tables using SQL scripts

# %%
execute_sql_script_from_file('./sql-scripts/01_create_tables.sql')
# Out:
# 🖥 Executing SQL script from file ./sql-scripts/01_create_tables.sql
# ✅ Successfully executed SQL script from file ./sql-scripts/01_create_tables.sql

# %% [markdown]
# ### 3.2 Populate tables with sample rows using SQL scripts

# %%
execute_sql_script_from_file('./sql-scripts/02_populate_tables.sql')
# Out:
# 🖥 Executing SQL script from file ./sql-scripts/02_populate_tables.sql
# ✅ Successfully executed SQL script from file ./sql-scripts/02_populate_tables.sql

# %% [markdown]
# ### 3.3 Print (query) all tables within the database

# %%
execute_sql_query('SELECT type, tbl_name FROM sqlite_master WHERE type="table";')
# Out:
# ✅ Query executed successfully. 3 rows to display.
# <style type="text/css">
# </style>
# <table id="T_0b5b0">
#   <thead>
#     <tr>
#       <th id="T_0b5b0_level0_col0" class="col_heading level0 col0" >type</th>
#       <th id="T_0b5b0_level0_col1" class="col_heading level0 col1" >tbl_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0b5b0_row0_col0" class="data row0 col0" >table</td>
#       <td id="T_0b5b0_row0_col1" class="data row0 col1" >departments</td>
#     </tr>
#     <tr>
#       <td id="T_0b5b0_row1_col0" class="data row1 col0" >table</td>
#       <td id="T_0b5b0_row1_col1" class="data row1 col1" >job_titles</td>
#     </tr>
#     <tr>
#       <td id="T_0b5b0_row2_col0" class="data row2 col0" >table</td>
#       <td id="T_0b5b0_row2_col1" class="data row2 col1" >employees</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.4 Query all departments

# %%
execute_sql_query('SELECT * FROM departments;')
# Out:
# ✅ Query executed successfully. 7 rows to display.
# <style type="text/css">
# </style>
# <table id="T_c48df">
#   <thead>
#     <tr>
#       <th id="T_c48df_level0_col0" class="col_heading level0 col0" >DepartmentID</th>
#       <th id="T_c48df_level0_col1" class="col_heading level0 col1" >DepartmentName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c48df_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_c48df_row0_col1" class="data row0 col1" >Engineering</td>
#     </tr>
#     <tr>
#       <td id="T_c48df_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_c48df_row1_col1" class="data row1 col1" >Human Resources</td>
#     </tr>
#     <tr>
#       <td id="T_c48df_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_c48df_row2_col1" class="data row2 col1" >Marketing</td>
#     </tr>
#     <tr>
#       <td id="T_c48df_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_c48df_row3_col1" class="data row3 col1" >Finance</td>
#     </tr>
#     <tr>
#       <td id="T_c48df_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_c48df_row4_col1" class="data row4 col1" >Operations</td>
#     </tr>
#     <tr>
#       <td id="T_c48df_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_c48df_row5_col1" class="data row5 col1" >Sales</td>
#     </tr>
#     <tr>
#       <td id="T_c48df_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_c48df_row6_col1" class="data row6 col1" >Legal</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.4 Query all job titles

# %%
execute_sql_query('SELECT * FROM job_titles;')
# Out:
# ✅ Query executed successfully. 8 rows to display.
# <style type="text/css">
# </style>
# <table id="T_ebec1">
#   <thead>
#     <tr>
#       <th id="T_ebec1_level0_col0" class="col_heading level0 col0" >JobTitleID</th>
#       <th id="T_ebec1_level0_col1" class="col_heading level0 col1" >JobTitle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ebec1_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ebec1_row0_col1" class="data row0 col1" >Software Engineer</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ebec1_row1_col1" class="data row1 col1" >HR Specialist</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ebec1_row2_col1" class="data row2 col1" >Marketing Manager</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ebec1_row3_col1" class="data row3 col1" >Data Analyst</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ebec1_row4_col1" class="data row4 col1" >Accountant</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ebec1_row5_col1" class="data row5 col1" >Operations Associate</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ebec1_row6_col1" class="data row6 col1" >Sales Executive</td>
#     </tr>
#     <tr>
#       <td id="T_ebec1_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_ebec1_row7_col1" class="data row7 col1" >Legal Counsel</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.4 Query first 10 rows in the employees table

# %%
execute_sql_query('SELECT * FROM employees LIMIT 10;')
# Out:
# ✅ Query executed successfully. 10 rows to display.
# <style type="text/css">
# </style>
# <table id="T_347a2">
#   <thead>
#     <tr>
#       <th id="T_347a2_level0_col0" class="col_heading level0 col0" >EmployeeID</th>
#       <th id="T_347a2_level0_col1" class="col_heading level0 col1" >FullName</th>
#       <th id="T_347a2_level0_col2" class="col_heading level0 col2" >StartDate</th>
#       <th id="T_347a2_level0_col3" class="col_heading level0 col3" >EndDate</th>
#       <th id="T_347a2_level0_col4" class="col_heading level0 col4" >DepartmentID</th>
#       <th id="T_347a2_level0_col5" class="col_heading level0 col5" >JobTitleID</th>
#       <th id="T_347a2_level0_col6" class="col_heading level0 col6" >Status</th>
#       <th id="T_347a2_level0_col7" class="col_heading level0 col7" >PayType</th>
#       <th id="T_347a2_level0_col8" class="col_heading level0 col8" >PayRate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_347a2_row0_col0" class="data row0 col0" >101</td>
#       <td id="T_347a2_row0_col1" class="data row0 col1" >Mary Nguyen</td>
#       <td id="T_347a2_row0_col2" class="data row0 col2" >2023-01-14</td>
#       <td id="T_347a2_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_347a2_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_347a2_row0_col5" class="data row0 col5" >5</td>
#       <td id="T_347a2_row0_col6" class="data row0 col6" >Active</td>
#       <td id="T_347a2_row0_col7" class="data row0 col7" >Salary</td>
#       <td id="T_347a2_row0_col8" class="data row0 col8" >58980.030000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row1_col0" class="data row1 col0" >102</td>
#       <td id="T_347a2_row1_col1" class="data row1 col1" >Jason Bentley</td>
#       <td id="T_347a2_row1_col2" class="data row1 col2" >2022-01-01</td>
#       <td id="T_347a2_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_347a2_row1_col4" class="data row1 col4" >5</td>
#       <td id="T_347a2_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_347a2_row1_col6" class="data row1 col6" >On-boarding</td>
#       <td id="T_347a2_row1_col7" class="data row1 col7" >Salary</td>
#       <td id="T_347a2_row1_col8" class="data row1 col8" >57109.490000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row2_col0" class="data row2 col0" >103</td>
#       <td id="T_347a2_row2_col1" class="data row2 col1" >Jennifer Bass</td>
#       <td id="T_347a2_row2_col2" class="data row2 col2" >2023-02-09</td>
#       <td id="T_347a2_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_347a2_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_347a2_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_347a2_row2_col6" class="data row2 col6" >Active</td>
#       <td id="T_347a2_row2_col7" class="data row2 col7" >Salary</td>
#       <td id="T_347a2_row2_col8" class="data row2 col8" >79423.950000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row3_col0" class="data row3 col0" >104</td>
#       <td id="T_347a2_row3_col1" class="data row3 col1" >Richard Lawson</td>
#       <td id="T_347a2_row3_col2" class="data row3 col2" >2023-04-07</td>
#       <td id="T_347a2_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_347a2_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_347a2_row3_col5" class="data row3 col5" >7</td>
#       <td id="T_347a2_row3_col6" class="data row3 col6" >Active</td>
#       <td id="T_347a2_row3_col7" class="data row3 col7" >Salary</td>
#       <td id="T_347a2_row3_col8" class="data row3 col8" >86216.920000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row4_col0" class="data row4 col0" >105</td>
#       <td id="T_347a2_row4_col1" class="data row4 col1" >Michael Dixon</td>
#       <td id="T_347a2_row4_col2" class="data row4 col2" >2021-12-19</td>
#       <td id="T_347a2_row4_col3" class="data row4 col3" >2022-04-29</td>
#       <td id="T_347a2_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_347a2_row4_col5" class="data row4 col5" >4</td>
#       <td id="T_347a2_row4_col6" class="data row4 col6" >Terminated</td>
#       <td id="T_347a2_row4_col7" class="data row4 col7" >Salary</td>
#       <td id="T_347a2_row4_col8" class="data row4 col8" >95147.340000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row5_col0" class="data row5 col0" >106</td>
#       <td id="T_347a2_row5_col1" class="data row5 col1" >Matthew Harvey</td>
#       <td id="T_347a2_row5_col2" class="data row5 col2" >2021-04-26</td>
#       <td id="T_347a2_row5_col3" class="data row5 col3" >2025-05-13</td>
#       <td id="T_347a2_row5_col4" class="data row5 col4" >7</td>
#       <td id="T_347a2_row5_col5" class="data row5 col5" >2</td>
#       <td id="T_347a2_row5_col6" class="data row5 col6" >Terminated</td>
#       <td id="T_347a2_row5_col7" class="data row5 col7" >Salary</td>
#       <td id="T_347a2_row5_col8" class="data row5 col8" >70996.660000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row6_col0" class="data row6 col0" >107</td>
#       <td id="T_347a2_row6_col1" class="data row6 col1" >Megan Walker</td>
#       <td id="T_347a2_row6_col2" class="data row6 col2" >2022-03-20</td>
#       <td id="T_347a2_row6_col3" class="data row6 col3" >2022-04-26</td>
#       <td id="T_347a2_row6_col4" class="data row6 col4" >1</td>
#       <td id="T_347a2_row6_col5" class="data row6 col5" >6</td>
#       <td id="T_347a2_row6_col6" class="data row6 col6" >Terminated</td>
#       <td id="T_347a2_row6_col7" class="data row6 col7" >Salary</td>
#       <td id="T_347a2_row6_col8" class="data row6 col8" >64845.640000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row7_col0" class="data row7 col0" >108</td>
#       <td id="T_347a2_row7_col1" class="data row7 col1" >William Carr</td>
#       <td id="T_347a2_row7_col2" class="data row7 col2" >2021-02-21</td>
#       <td id="T_347a2_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_347a2_row7_col4" class="data row7 col4" >1</td>
#       <td id="T_347a2_row7_col5" class="data row7 col5" >6</td>
#       <td id="T_347a2_row7_col6" class="data row7 col6" >Active</td>
#       <td id="T_347a2_row7_col7" class="data row7 col7" >Salary</td>
#       <td id="T_347a2_row7_col8" class="data row7 col8" >62209.900000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row8_col0" class="data row8 col0" >109</td>
#       <td id="T_347a2_row8_col1" class="data row8 col1" >Mark Lee</td>
#       <td id="T_347a2_row8_col2" class="data row8 col2" >2023-10-15</td>
#       <td id="T_347a2_row8_col3" class="data row8 col3" >None</td>
#       <td id="T_347a2_row8_col4" class="data row8 col4" >4</td>
#       <td id="T_347a2_row8_col5" class="data row8 col5" >2</td>
#       <td id="T_347a2_row8_col6" class="data row8 col6" >Active</td>
#       <td id="T_347a2_row8_col7" class="data row8 col7" >Salary</td>
#       <td id="T_347a2_row8_col8" class="data row8 col8" >62082.950000</td>
#     </tr>
#     <tr>
#       <td id="T_347a2_row9_col0" class="data row9 col0" >110</td>
#       <td id="T_347a2_row9_col1" class="data row9 col1" >Charles Watts</td>
#       <td id="T_347a2_row9_col2" class="data row9 col2" >2021-06-06</td>
#       <td id="T_347a2_row9_col3" class="data row9 col3" >None</td>
#       <td id="T_347a2_row9_col4" class="data row9 col4" >7</td>
#       <td id="T_347a2_row9_col5" class="data row9 col5" >8</td>
#       <td id="T_347a2_row9_col6" class="data row9 col6" >Active</td>
#       <td id="T_347a2_row9_col7" class="data row9 col7" >Salary</td>
#       <td id="T_347a2_row9_col8" class="data row9 col8" >123096.980000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🔍 4. Using SQL to Retrieve Information

# %% [markdown]
# ### 4.1 Find all on-boarding employees

# %%
execute_sql_query_from_file('./sql-scripts/03_all_onboarding_employees.sql')
# Out:
# 🖥 Executing SQL query from file ./sql-scripts/03_all_onboarding_employees.sql
# ✅ Query executed successfully. 5 rows to display.
# <style type="text/css">
# </style>
# <table id="T_19292">
#   <thead>
#     <tr>
#       <th id="T_19292_level0_col0" class="col_heading level0 col0" >FullName</th>
#       <th id="T_19292_level0_col1" class="col_heading level0 col1" >StartDate</th>
#       <th id="T_19292_level0_col2" class="col_heading level0 col2" >DepartmentName</th>
#       <th id="T_19292_level0_col3" class="col_heading level0 col3" >JobTitle</th>
#       <th id="T_19292_level0_col4" class="col_heading level0 col4" >PayType</th>
#       <th id="T_19292_level0_col5" class="col_heading level0 col5" >PayRate</th>
#       <th id="T_19292_level0_col6" class="col_heading level0 col6" >Status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_19292_row0_col0" class="data row0 col0" >Jason Bentley</td>
#       <td id="T_19292_row0_col1" class="data row0 col1" >2022-01-01</td>
#       <td id="T_19292_row0_col2" class="data row0 col2" >Operations</td>
#       <td id="T_19292_row0_col3" class="data row0 col3" >HR Specialist</td>
#       <td id="T_19292_row0_col4" class="data row0 col4" >Salary</td>
#       <td id="T_19292_row0_col5" class="data row0 col5" >57109.490000</td>
#       <td id="T_19292_row0_col6" class="data row0 col6" >On-boarding</td>
#     </tr>
#     <tr>
#       <td id="T_19292_row1_col0" class="data row1 col0" >Hannah Patterson</td>
#       <td id="T_19292_row1_col1" class="data row1 col1" >2023-09-04</td>
#       <td id="T_19292_row1_col2" class="data row1 col2" >Legal</td>
#       <td id="T_19292_row1_col3" class="data row1 col3" >Sales Executive</td>
#       <td id="T_19292_row1_col4" class="data row1 col4" >Salary</td>
#       <td id="T_19292_row1_col5" class="data row1 col5" >87444.450000</td>
#       <td id="T_19292_row1_col6" class="data row1 col6" >On-boarding</td>
#     </tr>
#     <tr>
#       <td id="T_19292_row2_col0" class="data row2 col0" >Lori Baker</td>
#       <td id="T_19292_row2_col1" class="data row2 col1" >2021-03-19</td>
#       <td id="T_19292_row2_col2" class="data row2 col2" >Finance</td>
#       <td id="T_19292_row2_col3" class="data row2 col3" >Software Engineer</td>
#       <td id="T_19292_row2_col4" class="data row2 col4" >Salary</td>
#       <td id="T_19292_row2_col5" class="data row2 col5" >93540.900000</td>
#       <td id="T_19292_row2_col6" class="data row2 col6" >On-boarding</td>
#     </tr>
#     <tr>
#       <td id="T_19292_row3_col0" class="data row3 col0" >Kevin Walters</td>
#       <td id="T_19292_row3_col1" class="data row3 col1" >2024-09-14</td>
#       <td id="T_19292_row3_col2" class="data row3 col2" >Marketing</td>
#       <td id="T_19292_row3_col3" class="data row3 col3" >Software Engineer</td>
#       <td id="T_19292_row3_col4" class="data row3 col4" >Salary</td>
#       <td id="T_19292_row3_col5" class="data row3 col5" >87913.350000</td>
#       <td id="T_19292_row3_col6" class="data row3 col6" >On-boarding</td>
#     </tr>
#     <tr>
#       <td id="T_19292_row4_col0" class="data row4 col0" >Jose Travis</td>
#       <td id="T_19292_row4_col1" class="data row4 col1" >2025-02-19</td>
#       <td id="T_19292_row4_col2" class="data row4 col2" >Sales</td>
#       <td id="T_19292_row4_col3" class="data row4 col3" >Data Analyst</td>
#       <td id="T_19292_row4_col4" class="data row4 col4" >Salary</td>
#       <td id="T_19292_row4_col5" class="data row4 col5" >65510.310000</td>
#       <td id="T_19292_row4_col6" class="data row4 col6" >On-boarding</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4.2. Find the number of employees by status

# %%
execute_sql_query_from_file('./sql-scripts/04_count_of_employees_by_status.sql')
# Out:
# 🖥 Executing SQL query from file ./sql-scripts/04_count_of_employees_by_status.sql
# ✅ Query executed successfully. 3 rows to display.
# <style type="text/css">
# </style>
# <table id="T_6a5c1">
#   <thead>
#     <tr>
#       <th id="T_6a5c1_level0_col0" class="col_heading level0 col0" >Status</th>
#       <th id="T_6a5c1_level0_col1" class="col_heading level0 col1" >NumEmployees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6a5c1_row0_col0" class="data row0 col0" >Active</td>
#       <td id="T_6a5c1_row0_col1" class="data row0 col1" >80</td>
#     </tr>
#     <tr>
#       <td id="T_6a5c1_row1_col0" class="data row1 col0" >On-boarding</td>
#       <td id="T_6a5c1_row1_col1" class="data row1 col1" >5</td>
#     </tr>
#     <tr>
#       <td id="T_6a5c1_row2_col0" class="data row2 col0" >Terminated</td>
#       <td id="T_6a5c1_row2_col1" class="data row2 col1" >15</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4.3 Calculate the average salary by department

# %%
execute_sql_query_from_file('./sql-scripts/05_average_salary_by_department.sql')
# Out:
# 🖥 Executing SQL query from file ./sql-scripts/05_average_salary_by_department.sql
# ✅ Query executed successfully. 7 rows to display.
# <style type="text/css">
# </style>
# <table id="T_23601">
#   <thead>
#     <tr>
#       <th id="T_23601_level0_col0" class="col_heading level0 col0" >DepartmentName</th>
#       <th id="T_23601_level0_col1" class="col_heading level0 col1" >NumEmployees</th>
#       <th id="T_23601_level0_col2" class="col_heading level0 col2" >AvgSalary</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23601_row0_col0" class="data row0 col0" >Engineering</td>
#       <td id="T_23601_row0_col1" class="data row0 col1" >9</td>
#       <td id="T_23601_row0_col2" class="data row0 col2" >88640.650000</td>
#     </tr>
#     <tr>
#       <td id="T_23601_row1_col0" class="data row1 col0" >Finance</td>
#       <td id="T_23601_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_23601_row1_col2" class="data row1 col2" >76376.540000</td>
#     </tr>
#     <tr>
#       <td id="T_23601_row2_col0" class="data row2 col0" >Human Resources</td>
#       <td id="T_23601_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_23601_row2_col2" class="data row2 col2" >70761.380000</td>
#     </tr>
#     <tr>
#       <td id="T_23601_row3_col0" class="data row3 col0" >Legal</td>
#       <td id="T_23601_row3_col1" class="data row3 col1" >14</td>
#       <td id="T_23601_row3_col2" class="data row3 col2" >89787.950000</td>
#     </tr>
#     <tr>
#       <td id="T_23601_row4_col0" class="data row4 col0" >Marketing</td>
#       <td id="T_23601_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_23601_row4_col2" class="data row4 col2" >77145.530000</td>
#     </tr>
#     <tr>
#       <td id="T_23601_row5_col0" class="data row5 col0" >Operations</td>
#       <td id="T_23601_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_23601_row5_col2" class="data row5 col2" >76667.980000</td>
#     </tr>
#     <tr>
#       <td id="T_23601_row6_col0" class="data row6 col0" >Sales</td>
#       <td id="T_23601_row6_col1" class="data row6 col1" >15</td>
#       <td id="T_23601_row6_col2" class="data row6 col2" >93023.430000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4.4 Find employees hired during or after 2025

# %%
execute_sql_query_from_file('./sql-scripts/06_employees_hired_after_2025.sql')
# Out:
# 🖥 Executing SQL query from file ./sql-scripts/06_employees_hired_after_2023.sql
# ✅ Query executed successfully. 10 rows to display.
# <style type="text/css">
# </style>
# <table id="T_4caa8">
#   <thead>
#     <tr>
#       <th id="T_4caa8_level0_col0" class="col_heading level0 col0" >FullName</th>
#       <th id="T_4caa8_level0_col1" class="col_heading level0 col1" >StartDate</th>
#       <th id="T_4caa8_level0_col2" class="col_heading level0 col2" >DepartmentName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4caa8_row0_col0" class="data row0 col0" >Lauren Dominguez</td>
#       <td id="T_4caa8_row0_col1" class="data row0 col1" >2025-06-02</td>
#       <td id="T_4caa8_row0_col2" class="data row0 col2" >Sales</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row1_col0" class="data row1 col0" >Jerry Christensen</td>
#       <td id="T_4caa8_row1_col1" class="data row1 col1" >2025-05-15</td>
#       <td id="T_4caa8_row1_col2" class="data row1 col2" >Human Resources</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row2_col0" class="data row2 col0" >Ricky Larson</td>
#       <td id="T_4caa8_row2_col1" class="data row2 col1" >2025-05-13</td>
#       <td id="T_4caa8_row2_col2" class="data row2 col2" >Engineering</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row3_col0" class="data row3 col0" >Haley Arnold</td>
#       <td id="T_4caa8_row3_col1" class="data row3 col1" >2025-02-22</td>
#       <td id="T_4caa8_row3_col2" class="data row3 col2" >Engineering</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row4_col0" class="data row4 col0" >Jose Travis</td>
#       <td id="T_4caa8_row4_col1" class="data row4 col1" >2025-02-19</td>
#       <td id="T_4caa8_row4_col2" class="data row4 col2" >Sales</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row5_col0" class="data row5 col0" >Stacy Freeman</td>
#       <td id="T_4caa8_row5_col1" class="data row5 col1" >2025-02-14</td>
#       <td id="T_4caa8_row5_col2" class="data row5 col2" >Finance</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row6_col0" class="data row6 col0" >Joseph Santos</td>
#       <td id="T_4caa8_row6_col1" class="data row6 col1" >2025-02-06</td>
#       <td id="T_4caa8_row6_col2" class="data row6 col2" >Operations</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row7_col0" class="data row7 col0" >Nathan Stewart</td>
#       <td id="T_4caa8_row7_col1" class="data row7 col1" >2025-01-29</td>
#       <td id="T_4caa8_row7_col2" class="data row7 col2" >Marketing</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row8_col0" class="data row8 col0" >John Anderson</td>
#       <td id="T_4caa8_row8_col1" class="data row8 col1" >2025-01-24</td>
#       <td id="T_4caa8_row8_col2" class="data row8 col2" >Marketing</td>
#     </tr>
#     <tr>
#       <td id="T_4caa8_row9_col0" class="data row9 col0" >Gary Craig</td>
#       <td id="T_4caa8_row9_col1" class="data row9 col1" >2025-01-22</td>
#       <td id="T_4caa8_row9_col2" class="data row9 col2" >Finance</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🔒 5. Using SQL to Impose Data Integrity

# %% [markdown]
# ### 5.1 Prevent duplicate `DepartmentID`

# %%
execute_sql_query('''
    INSERT INTO departments (DepartmentID, DepartmentName) 
    VALUES (1, 'Sales'); -- ⚠️ DepartmentID == 1 already exists in the departments table
''')
# Out:
# ❌ An error occurred: UNIQUE constraint failed: departments.DepartmentID

# %% [markdown]
# 🔍 Why it fails: `DepartmentID = 1` already exists. This is a primary key constraint violation.

# %% [markdown]
# #### Correct Query

# %% [markdown]
# Note: Running this query multiple times will keep adding an extra row to the `departments` table with duplicate `DepartmentName` value (`'Sales'`). This is because we have not added a `UNIQUE` constraint to the `DepartmentName` column.

# %%
execute_sql_query('''
    INSERT INTO departments (DepartmentName) 
    VALUES ('Sales');
''')
# Out:
# ✅ Query executed successfully. No results to display.

# %% [markdown]
# Check the result.

# %%
execute_sql_query('''
    SELECT * FROM departments;
''')
# Out:
# ✅ Query executed successfully. 8 rows to display.
# <style type="text/css">
# </style>
# <table id="T_ce6ea">
#   <thead>
#     <tr>
#       <th id="T_ce6ea_level0_col0" class="col_heading level0 col0" >DepartmentID</th>
#       <th id="T_ce6ea_level0_col1" class="col_heading level0 col1" >DepartmentName</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ce6ea_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ce6ea_row0_col1" class="data row0 col1" >Engineering</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ce6ea_row1_col1" class="data row1 col1" >Human Resources</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ce6ea_row2_col1" class="data row2 col1" >Marketing</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ce6ea_row3_col1" class="data row3 col1" >Finance</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ce6ea_row4_col1" class="data row4 col1" >Operations</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ce6ea_row5_col1" class="data row5 col1" >Sales</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ce6ea_row6_col1" class="data row6 col1" >Legal</td>
#     </tr>
#     <tr>
#       <td id="T_ce6ea_row7_col0" class="data row7 col0" >8</td>
#       <td id="T_ce6ea_row7_col1" class="data row7 col1" >Sales</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 5.2 Prevent a duplicate `JobTitle` value

# %%
execute_sql_query('''
    INSERT INTO job_titles (JobTitle) 
    VALUES ('Software Engineer'); -- ⚠️ `Software Engineer` already exists in the 
''')
# Out:
# ❌ An error occurred: UNIQUE constraint failed: job_titles.JobTitle

# %% [markdown]
# ### 5.3 Prevent a negative `PayRate` value

# %%
execute_sql_query('''
    INSERT INTO employees (
        EmployeeID,
        FullName,
        StartDate,
        EndDate,
        DepartmentID,
        JobTitleID,
        Status,
        PayType,
        PayRate
    ) VALUES (
        108,
        'Ivan Keith',
        '2023-01-01',
        NULL,
        1,
        1,
        'Active',
        'Hourly',
        -25.00 -- ⚠️ PayRate is a negative amount
    );
''')
# Out:
# ❌ An error occurred: CHECK constraint failed: PayRate > 0

# %% [markdown]
# 🔍 Why it fails: `PayRate` < 0 violates the `CHECK` constraint (`PayRate` > 0)

# %% [markdown]
# ### 5.4 Prevent an `EndDate` that is earlier than the `StartDate`

# %%
execute_sql_query('''
    INSERT INTO employees (
        EmployeeID,
        FullName,
        StartDate,
        EndDate,
        DepartmentID,
        JobTitleID,
        Status,
        PayType,
        PayRate
    ) VALUES (
        109,
        'Jenny Park',
        '2024-01-01',
        '2022-12-01', -- ⚠️ EndDate is 2022, while the start date is 2024
        1,
        1,
        'Terminated',
        'Salary',
        80000
    );
''')
# Out:
# ❌ An error occurred: CHECK constraint failed: EndDate IS NULL OR EndDate >= StartDate

# %% [markdown]
# 🔍 Why it fails: `EndDate` < `StartDate` → `CHECK` constraint violation (`EndDate IS NULL OR EndDate >= StartDate`)

# %% [markdown]
# ### 5.5 Prevent an invalid employee `Status` value

# %%
execute_sql_query('''
    INSERT INTO employees (
        EmployeeID,
        FullName,
        StartDate,
        EndDate,
        DepartmentID,
        JobTitleID,
        Status,
        PayType,
        PayRate
    ) VALUES (
        107,
        'Hannah Yoo',
        '2023-09-01',
        NULL,
        1,
        1,
        'Actiive', -- ⚠️ Invalid status (typo) - should be 'Active' instead of 'Actiive'
        'Salary',
        75000
    );
''')
# Out:
# ❌ An error occurred: CHECK constraint failed: Status IN ('Active', 'On-boarding', 'Terminated')

# %% [markdown]
# 🔍 Why it fails: 'Actiive' is not one of the allowed values according to the `CHECK` constraint on `Status` (`IN ('Active', 'On-boarding', 'Terminated')`)

# %% [markdown]
# ## ✅ 6. Summary and Next Steps
# In this notebook, we built a simple SQLite database to demonstrate key data governance principles: unique identifiers, referential integrity, and validation rules through constraints. These foundations are essential in building systems that are reliable, auditable, and secure. In future lessons, you may extend this database with more advanced concepts such as triggers, views, and real-time data validation.
